# %% [markdown]
# # Entanglement

# %% [markdown]
# Below is a simply circuit to generate an entangled state. Specifically the Bell state
#
# $$
# \begin{align*}
# \ket{\Phi^+} &= \frac{1}{\sqrt{2}}(\ket{0}_A \otimes \ket{0}_B ) + \frac{1}{\sqrt{2}}(\ket{1}_A \otimes \ket{1}_B ) \\
# &= \frac{1}{\sqrt{2}}\ket{00} + \frac{1}{\sqrt{2}}\ket{11}
# \end{align*}
# $$

# %%
from IPython.display import Image
display(Image("img/bell_circ.png", width=600))

# %% [markdown]
# If two systems are entangled they are entangled in *every* basis.

# %%
# %load_ext watermark
# %watermark -n -u -v -iv
# Out:
# Last updated: Sat Jul 06 2024
#
# Python implementation: CPython
# Python version       : 3.10.12
# IPython version      : 8.22.2
